# %%
import numpy as np
import os

# %%
workdir = "/lustre/work/ws/ws1/ka_he8978-dipeptide/training/10_amp_qmmm/B2-PLYP_def2-QZVPP_D3BJ/02_group_1-20/results/AMPQMMM_model_1745162557"
os.chdir(workdir)

# %%
parameter_file = "parameters.npy"

parameters = np.load(parameter_file, allow_pickle=True).item()

# %%
print(parameters["cutoff_lr"])
parameters["cutoff_lr"] = 5000.0
# Out:
# 5000.0

# %%
np.save(parameter_file, parameters, allow_pickle=True)
print("Updated parameters saved to", parameter_file)
# Out:
# Updated parameters saved to parameters.npy
